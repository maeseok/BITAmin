# %%
import pandas as pd
df = pd.read_excel("etc.xlsx")
df
# Out:
#                                           dialect_form  \
# 0               이 마을의 형성에 대헤서 말씀헤 주십시오. 이 마을은 청수리잖아예.
# 1              만들어진 역사란 말이지예. 형성. 이 마을은 어떵 헹 만들어졌습니까?
# 2                        들은 얘기를 갈으믄 뒈마씨. 무사 청수리옌 헤신고예?
# 3                                           형님부터 말허쿠과?
# 4    우리 청수리는 저지 본향 청수라고 허는데 금악 본향 저지 잇고, 저 지 본향 청수 ...
# ..                                                 ...
# 244                                          아팡마씨? 어떵?
# 245                                 아이고, 인물 나와신게. 청수도.
# 246                  참, 게도 인물도 나고 근데 인명은 재천이라부난 어떵헙니까?
# 247                           에, 아니우다게. 요즘은 백세시대렌 헴수게.
# 248                                        아니우다게. 그레도.
#
#                                          standard_form  isDialect  len
# 0               이 마을의 형성에 대해서 말씀해 주십시 오. 이 마을은 청수리잖아요.        NaN   38
# 1            만들어진 역사란 말이지요. 형성. 이 마을은 어떻게 해 서 만들어졌습니까?        NaN   39
# 2                         들은 얘기를 말하면 되요. 왜 청수리라고 했는가요?        NaN   29
# ...

# %%
df['isDialect'] = df['dialect_form'] != df['standard_form']
#df.to_csv('etc.csv')
df
# Out:
#                                           dialect_form  \
# 0               이 마을의 형성에 대헤서 말씀헤 주십시오. 이 마을은 청수리잖아예.
# 1              만들어진 역사란 말이지예. 형성. 이 마을은 어떵 헹 만들어졌습니까?
# 2                        들은 얘기를 갈으믄 뒈마씨. 무사 청수리옌 헤신고예?
# 3                                           형님부터 말허쿠과?
# 4    우리 청수리는 저지 본향 청수라고 허는데 금악 본향 저지 잇고, 저 지 본향 청수 ...
# ..                                                 ...
# 244                                          아팡마씨? 어떵?
# 245                                 아이고, 인물 나와신게. 청수도.
# 246                  참, 게도 인물도 나고 근데 인명은 재천이라부난 어떵헙니까?
# 247                           에, 아니우다게. 요즘은 백세시대렌 헴수게.
# 248                                        아니우다게. 그레도.
#
#                                          standard_form  isDialect  len
# 0               이 마을의 형성에 대해서 말씀해 주십시 오. 이 마을은 청수리잖아요.       True   38
# 1            만들어진 역사란 말이지요. 형성. 이 마을은 어떻게 해 서 만들어졌습니까?       True   39
# 2                         들은 얘기를 말하면 되요. 왜 청수리라고 했는가요?       True   29
# ...

# %%
test=pd.read_csv('etc.csv')
test
# Out:
#      Unnamed: 0                                       dialect_form  \
# 0             0             이 마을의 형성에 대헤서 말씀헤 주십시오. 이 마을은 청수리잖아예.
# 1             1            만들어진 역사란 말이지예. 형성. 이 마을은 어떵 헹 만들어졌습니까?
# 2             2                      들은 얘기를 갈으믄 뒈마씨. 무사 청수리옌 헤신고예?
# 3             3                                         형님부터 말허쿠과?
# 4             4  우리 청수리는 저지 본향 청수라고 허는데 금악 본향 저지 잇고, 저 지 본향 청수 ...
# ..          ...                                                ...
# 244         244                                          아팡마씨? 어떵?
# 245         245                                 아이고, 인물 나와신게. 청수도.
# 246         246                  참, 게도 인물도 나고 근데 인명은 재천이라부난 어떵헙니까?
# 247         247                           에, 아니우다게. 요즘은 백세시대렌 헴수게.
# 248         248                                        아니우다게. 그레도.
#
#                                          standard_form  isDialect  len
# 0               이 마을의 형성에 대해서 말씀해 주십시 오. 이 마을은 청수리잖아요.       True   38
# ...
