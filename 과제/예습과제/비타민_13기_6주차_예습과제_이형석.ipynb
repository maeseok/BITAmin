# %% [markdown]
# ## 문제1

# %% [markdown]
# 인공지능분야 쪽에서 유명한 랩실 중 1개인 DSBA강의입니다.
#
# RNN, LSTM, GRU에 대한 강의와 강의자료 업로드 해놓았습니다.
# 강의를 보고 RNN, LSTM, GRU에 대해서 설명해 주시면 됩니다.(코드문제없습니다.)
#
# 강의자료는 비타민 예습과제란에 있습니다.
#
# [강의] : https://www.youtube.com/watch?v=006BjyZicCo
#
# RNN을 대략적으로 설명해 주시고, LSTM과 GRU는 어떠한 문제를 보안했고 어떻게 보안했는지 설명해 주시면 됩니다.

# %% [markdown]
# [설명란]

# %%
RNN은 예를 들어 t시점일 때 t-1 시점의 데이터를 사용하여 히든 벡터를 계산한다.
즉 이전 정보들이 순환하여 입력되어 과거 데이터를 현재 시점에 이용할 수 있다.

LSTM은 RNN의 장기 의존성 문제를 완화했다. 이는 히든 벡터를 구할 때 Cell state
구조를 사용하여 장기적으로 정보들을 유지할 수 있게하였고, 
Forget gate, Input gate, Output gate를 추가하여 히든 벡터를 구해
기울기 소실 문제를 해결했다.

GRU는 LSTM의 복잡한 과정을 경량화하여 update gate, reset gate와 hidde state를
사용해 기울기 소실 문제를 해결했다.
# Out:
#   Cell In[1], line 1
#     RNN은 예를 들어 t시점일 때 t-1 시점의 데이터를 사용하여 히든 벡터를 계산한다.
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2-1. Attention 메커니즘은 Seq2Seq모델의 어떤 한계를 극복하기 위해 등장했는지 서술하시오.

# %% [markdown]
# 답 : 정보 손실, 기울기 소실

# %% [markdown]
# ## 2-2. 아래의 빈칸을 채우시오.
# Attention은 중요한 단어에 집중하여 _Decoder_에 바로 전달하는 기법이다.

# %% [markdown]
# 답 : Decoder

# %% [markdown]
# ## 2-3. Attention 메커니즘을 사용하는 딥러닝 모델을 고르시오.
# a) GAN (Generative Adversarial Network)\
# b) RNN (Recurrent Neural Network)\
# c) CNN (Convolutional Neural Network)\
# d) LSTM (Long Short-Term Memory)\

# %%
답 : d

# %% [markdown]
# ## 2-4. 아래의 빈칸을 채우시오.
# Attetion Score란 현재 예측의 시점 t에서 단어를 예측하기 위해, 인코더의 모든 은닉 상태 각각이 디코더의 현 시점의 은닉 상태와 얼마나 유사한지를 판단하는 스코어값이다. SoftMax 함수를 적용하여 정규화한 값을 사용한다.

# %% [markdown]
# ## 2-5. 다음의 그림을 참고하여 a-e 항목을 Attention 매커니즘의 단계를 순서대로 나열하시오
# ### 1.
# ![image.png](attachment:image.png)
# ### 2.
# ![image-2.png](attachment:image-2.png)
# ### 3.
# ![image-3.png](attachment:image-3.png)
# ### 4.
# ![image-4.png](attachment:image-4.png)
#
#
# a. Attention score에 softmax를 취해 각각의 점수를 확률 분포로 변화(Normalize)시킨다.\
# b. 디코더 hidden vector와 인풋 hidden vector 사이의 attention score를 구한다.\
# c. Attention Output인 인코더 가중합된 정보와 디코더의 hidden state을 이용해          이번 단계의 결과를 예측하는데 사용한다.\
# d. 확률값으로 나타낸 Attention distribution을 이용해 인코더의 hidden state들의 가중합 벡터 생성한다.

# %% [markdown]
# 답 : b-a-c-d

# %% [markdown]
# ## 문제3

# %% [markdown]
# ## 3-1. 아래의 빈칸을 채우시오.
# 트랜스포머는 입력문장을 이해하는 인코더와 타깃문장을 생성하는 디코더에 모두 어텐션을 사용한다.

# %% [markdown]
# ## 3-2. 다음은 트랜스포머의 구조이다. 2-1문제를 참고해 빈칸을 채우시오.
# ![image.png](attachment:image.png)

# %% [markdown]
# 답 : 인코더, 디코더

# %% [markdown]
# ## 3-3. 아래는 self 어텐션을 통해 문장 내 단어끼리의 유사도를 시각적으로 표현한 그림과 self attention의 구조를 표현한 그림이다. 두 그림을 활용해 트랜스포머의 셀프 어텐션이 무엇인지 설명하시오.
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# 답 : 자기 자신이 가지는 단어들을 활용해 유사도를 계산한다.

# %% [markdown]
# ## 3-4.트랜스포머의 사용 분야에 대해 간단히 서술하시오.

# %% [markdown]
# 답 : 이상탐지, CV, NLP
