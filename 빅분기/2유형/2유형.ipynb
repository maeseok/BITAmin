# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e6_p1_1.csv')
df.head(5)
# Out:
#              구급보고서번호   소방서명 환자증상구분명1      신고일자    신고시각      출동일자    출동시각  \
# 0  20211122103M01526  중랑소방서     심계항진  20210330  104800  20210330  105042
# 1  20211111105M00771  노원소방서       복통  20210412  225600  20210412  225827
# 2  20211115104M00864  서초소방서     심계항진  20210303  194100  20210303  194500
# 3  20211113107M01869  마포소방서       고열  20211225  235400  20211226     331
# 4  20211118102M05820  강동소방서       고열  20211019   12100  20211019   12322
#
#   환자직업명 사고발생장소
# 0    무직      집
# 1    기타      집
# 2   직장인   상업시설
# 3    유아      집
# 4    무직      집

# %%
df['소요시각'] = (
                pd.to_datetime(
                    df['출동일자'].astype('str') + df['출동시각'].astype('str').str.zfill(6)
                )

                - 
    
                pd.to_datetime(
                    df['신고일자'].astype('str') + df['신고시각'].astype('str').str.zfill(6)
                )
                ).dt.total_seconds()

# %%
result = df.groupby(['소방서명'])['소요시각'].mean().sort_values()
print(result)
# Out:
# 소방서명
# 서초소방서     164.883495
# 서대문소방서    165.056604
# 종로소방서     175.500000
# 광진소방서     175.602273
# 노원소방서     179.579310
# 강동소방서     181.656566
# 동작소방서     185.107527
# 송파소방서     189.330508
# 구로소방서     189.513274
# 은평소방서     191.390071
# 양천소방서     192.201389
# 마포소방서     196.547445
# 강남소방서     196.933333
# 강서소방서     199.696203
# 중랑소방서     204.877049
# 성북소방서     205.293578
# 도봉소방서     207.145631
# 성동소방서     207.358209
# 중부소방서     207.563636
# 관악소방서     209.843750
# 강북소방서     212.061224
# 동대문소방서    228.148515
# 용산소방서     237.366197
# 영등포소방서    258.839286
# Name: 소요시각, dtype: float64

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e6_p1_2.csv')
df.head(5)
# Out:
#                학교명  시도  학교세부유형  일반학급_학생수_계  교원수_총계_계
# 0  서울대학교사범대학부설고등학교  서울  일반고등학교         689        73
# 1           가락고등학교  서울  일반고등학교         765        70
# 2           개포고등학교  서울  일반고등학교         684        69
# 3           경기고등학교  서울  일반고등학교        1047        96
# 4           경동고등학교  서울  일반고등학교         529        58

# %%
data = df[df.학교세부유형=='일반중학교']['시도'].value_counts().index[1]

df2 = df[(df.학교세부유형=='일반중학교') & (df.시도==data)]
df2
# Out:
#          학교명  시도 학교세부유형  일반학급_학생수_계  교원수_총계_계
# 230    동원중학교  서울  일반중학교         379        36
# 231    면목중학교  서울  일반중학교         462        42
# 232    봉화중학교  서울  일반중학교         256        31
# 233    성일중학교  서울  일반중학교         313        30
# 234    신현중학교  서울  일반중학교         683        52
# ..       ...  ..    ...         ...       ...
# 612  동구여자중학교  서울  일반중학교         298        29
# 613  성신여자중학교  서울  일반중학교         590        46
# 614  성암여자중학교  서울  일반중학교         403        32
# 615  창문여자중학교  서울  일반중학교         471        35
# 616  한성여자중학교  서울  일반중학교         374        32
#
# [387 rows x 5 columns]

# %%
df2['total'] = df.일반학급_학생수_계 / df.교원수_총계_계
df2.sort_values(by='total',ascending=False)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_19016\2046953870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['total'] = df.일반학급_학생수_계 / df.교원수_총계_계
#                 학교명  시도 학교세부유형  일반학급_학생수_계  교원수_총계_계      total
# 524  단국대학교사범대학부속중학교  서울  일반중학교         606        33  18.363636
# 444           한영중학교  서울  일반중학교         742        43  17.255814
# 532         진선여자중학교  서울  일반중학교         997        58  17.189655
# 441           배재중학교  서울  일반중학교         868        51  17.019608
# 526           휘문중학교  서울  일반중학교         814        48  16.958333
# ..              ...  ..    ...         ...       ...        ...
# 438           동북중학교  서울  일반중학교         233        43   5.418605
# ...

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e6_p1_3.csv')
df.head(5)
# Out:
#        범죄분류     절도     사기   배임   방화     폭행
# 0  2018년_1월  13280  25318  656  143  12186
# 1  2018년_2월  12504  19159  403  135  12087
# 2  2018년_3월  14733  24509  471  148  13841
# 3  2018년_4월  14781  23147  414  135  13973
# 4  2018년_5월  15988  23584  451  127  14117

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/ep6_p2_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/ep6_p2_test.csv')

target = train.pop('General_Health')

# %%
train_id = train.pop('ID')
test_id = test.pop('ID')

# %%
col = train.select_dtypes(include='object').columns
train = pd.get_dummies(train,columns=col)
test = pd.get_dummies(test,columns=col)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(train,target)
pred = model.predict(test)

# %%
pd.DataFrame({'ID':test_id, 'price':pred})
# Out:
#             ID      price
# 0     ID_14547  Excellent
# 1        ID_26  Excellent
# 2     ID_14103       Good
# 3     ID_10946  Excellent
# 4      ID_1572  Excellent
# ...        ...        ...
# 4808  ID_12991  Excellent
# 4809  ID_13295       Good
# 4810   ID_2428       Fair
# 4811  ID_12719       Good
# 4812  ID_12691  Excellent
#
# [4813 rows x 2 columns]

# %%
import scipy
help(scipy.stats.chi2_contingency)
# Out:
# Help on function chi2_contingency in module scipy.stats.contingency:
#
# chi2_contingency(observed, correction=True, lambda_=None)
#     Chi-square test of independence of variables in a contingency table.
#
#     This function computes the chi-square statistic and p-value for the
#     hypothesis test of independence of the observed frequencies in the
#     contingency table [1]_ `observed`.  The expected frequencies are computed
#     based on the marginal sums under the assumption of independence; see
#     `scipy.stats.contingency.expected_freq`.  The number of degrees of
#     freedom is (expressed using numpy functions and attributes)::
#
#         dof = observed.size - sum(observed.shape) + observed.ndim - 1
#
#
#     Parameters
#     ----------
#     observed : array_like
#         The contingency table. The table contains the observed frequencies
#         (i.e. number of occurrences) in each category.  In the two-dimensional
# ...

# %%
from scipy.stats import chi2_contingency
import numpy as np
# 남성과 여성의 인구 수
total_male = 600
total_female = 550

# 남성과 여성 중 흡연자의 비율
smoking_ratio_male = 0.2
smoking_ratio_female = 0.26

# 흡연자와 비흡연자의 인구 수 계산
smoking_male = int(total_male * smoking_ratio_male)
non_smoking_male = int(total_male - smoking_male)

smoking_female = total_female * smoking_ratio_female
non_smoking_female = total_female - smoking_female
data = np.array([[smoking_male, non_smoking_male], [smoking_female, non_smoking_female]])

alpha = 0.05

t_stat, p_value, dof, expected = chi2_contingency(data)

if p_value<alpha:
    print('귀무가설 기각', p_value)
else:
    print('귀무가설 채택')
# Out:
# 귀무가설 기각 0.018786854975740765

# %%
import pandas as pd 
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/adp/28/p7.csv')
df.head()
# Out:
#    age  Cholesterol  weight
# 0   65         69.0   111.0
# 1   54        117.0    81.0
# 2   61         86.2    72.0
# 3   57         76.0    78.0
# 4   62        160.0    61.0

# %%
from statsmodels.formula.api import ols

model = ols('weight~age+Cholesterol',data=df)
results = model.fit()
results.summary()
results.params['age']
# Out:
# -0.03610166914386536

# %%
alpha=0.05

result = ols('weight~Cholesterol',data=df).fit()
#result.summary()


if result.pvalues['Cholesterol']<alpha:
    print('선형 관계에 있다')
else:
    print('선형 관계에 없다.')
# Out:
# 선형 관계에 있다

# %%
data = pd.DataFrame({'age':[55],'Cholesterol':[72.6]})

print(results.predict(data)[0])
# Out:
# 78.8577101134459

# %% [markdown]
# # 7회

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p1.csv')
df.head(5)
# Out:
#      학생    국어    수학    영어    과학
# 0  ID_0  63.0   NaN  79.0  84.0
# 1  ID_1  91.0  93.0   NaN  73.0
# 2  ID_2  59.0  55.0   NaN  56.0
# 3  ID_3  71.0  83.0  82.0   NaN
# 4  ID_4  62.0  72.0  56.0   NaN

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df['국어'] = ss.fit_transform(df[['국어']])
df['국어'].max()
#cols = ['국어','수학','영어','과학']
#for i in cols:
#    df[col] = ss.fit_transform(df[col])
# Out:
# 1.7138556887128247

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_.csv')
df.head(5)
# Out:
#       var_1     var_2     var_3     var_4     var_5     var_6     var_7  \
# 0 -0.335864 -2.425701  0.452851 -1.381924 -0.425591 -1.461498 -0.417082
# 1  0.803535 -0.699433  0.095579  0.788053 -0.267674 -0.370746  0.636034
# 2 -0.408470 -0.361105 -0.857278  0.338294  2.317821 -0.099928  0.557053
# 3 -0.690599  0.777928 -0.079963  0.164086  1.721702  0.146761 -0.988636
# 4  0.179819 -0.668267  0.381849 -0.884196  0.758519 -1.026190  0.986227
#
#       var_8     var_9    var_10  ...    var_23    var_24    var_25    var_26  \
# 0 -0.944226 -0.351224  1.474046  ...  1.715714  0.300227  0.439828 -0.094772
# 1 -1.674584 -0.058465 -1.188973  ... -1.348879 -0.899480 -1.271886  0.333734
# 2 -0.847932  0.973471  0.101203  ... -0.388353  0.918553 -1.984422  0.385055
# 3  0.885344  0.647053  0.674609  ...  0.337074 -1.406224 -0.699728 -0.836068
# 4 -1.663167  2.290551  0.564845  ... -0.700137 -0.153825 -1.835313  0.182131
#
#      var_27    var_28    var_29    var_30    var_31    var_32
# ...

# %%
df[abs(df.corr()['var_11']).sort_values(ascending=False).index[1]].mean()
# Out:
# -0.06289356546077182

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3.csv')
df.head(5)
# Out:
#       var_1     var_2     var_3     var_4     var_5     var_6     var_7  \
# 0 -0.401584  0.007198 -0.134910 -0.419514 -0.686331 -1.174550 -0.499150
# 1  1.064622 -0.531247  0.571185 -0.762243 -1.456043  0.355432  0.880010
# 2  0.900195 -1.148496 -0.718437 -2.315266 -0.755505  0.630923  0.586027
# 3  1.199227 -0.114200  0.101536 -1.851971 -0.672844  0.796077  0.644246
# 4  0.607393  1.675917  1.063759 -0.799493 -0.959568 -0.103007 -0.245984
#
#       var_8     var_9    var_10    var_11    var_12
# 0 -0.557510  0.357347  0.844209  0.082097  0.475098
# 1  0.523183 -0.141733  0.301472  0.840299 -0.045113
# 2  0.086497 -0.381657 -1.602532  1.566340 -0.654105
# 3 -0.836296 -1.707074  0.376281  1.303967  1.228015
# 4 -0.059492  0.293592 -0.517044  0.100772  0.403833

# %%
q1 = df['var_6'].quantile(0.25)
q3 = df['var_6'].quantile(0.75)
iqr = q3-q1

min_ = q1 - 1.5 * iqr
max_ = q3 + 1.5 * iqr
iqr =  df['var_6'].quantile(0.75) -  df['var_6'].quantile(0.25)
df[(df['var_6']>q3+1.5*iqr) | (df['var_6']<q1-1.5*iqr)]
# Out:
#         var_1     var_2     var_3     var_4     var_5     var_6     var_7  \
# 61  -1.052026  2.671477 -0.063735  0.443091 -0.252952 -2.896629 -1.356372
# 80   2.601718 -0.689163  0.187056 -0.333682 -2.656683  2.704264  2.525497
# 94   0.945275 -1.588204  0.265805 -0.599865 -0.715023  2.824044  1.949872
# 148 -0.469255 -0.518196 -0.880794 -1.353235  0.107554 -2.727164 -0.949754
# 164  1.649083 -1.819321 -0.747122 -1.675070 -0.100709  2.620420  2.573300
# 282 -2.341044 -0.742030 -0.160838 -0.802164  1.180016 -2.511238 -2.128845
# 399  0.228232 -1.704387 -1.788963 -0.418815  0.570391  2.767266  1.329747
# 406  2.284573 -0.907189  1.668205 -0.340220 -2.328300  2.870425  2.622832
#
#         var_8     var_9    var_10    var_11    var_12
# 61  -2.357715  0.639064  2.670374  1.449786  0.797494
# 80   0.963460 -0.383575 -0.839918 -0.440121 -0.844644
# 94  -0.040541  0.834281 -0.689715 -1.907044 -1.174152
# 148 -1.205864 -0.501184 -0.188367  1.197877  1.438212
# ...

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_train2.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_test2.csv')

display(train.head(2))
test.head(2)
# Out:
#         ID      연월  업종명 이용자구분    성별  이용자수   이용건수        이용금액
# 0  ID_5020  202201  여관업    법인  알수없음  7693  12105  3049021809
# 1  ID_5021  202201  여관업  제주도민    남성  3990   4291   294163241
#         ID      연월         업종명 이용자구분    성별    이용자수    이용건수
# 0  ID_2575  201911     한식 음식점업  제주도민    여성  153363  163462
# 1  ID_6637  202305  건강보조식품 소매업    법인  알수없음     136     144

# %%
target=train.pop('이용금액')

# %%
train_id = train.pop('ID')
test_id = test.pop('ID')

# %%
col = train.select_dtypes(include='object').columns
train = pd.get_dummies(train,columns=col)
test = pd.get_dummies(test,columns=col)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(train,target)
pred = model.predict(test)

# %%
pd.DataFrame({'ID':test_id,'price':pred})
# Out:
#            ID         price
# 0     ID_2575  6.053216e+09
# 1     ID_6637  3.984637e+07
# 2     ID_5704  2.418051e+06
# 3     ID_3606  1.646331e+06
# 4     ID_6443  5.520289e+05
# ...       ...           ...
# 5015  ID_4523  3.970096e+08
# 5016  ID_3483  1.129917e+08
# 5017   ID_453  5.490975e+09
# 5018   ID_998  9.354370e+08
# 5019  ID_3237  6.467696e+08
#
# [5020 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3_1.csv')
df.head()
# Out:
#       Target        v1        v2        v3        v4        v5        v6  \
# 0  21.650072  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# 1 -19.469855 -0.225776  0.067528 -1.424748 -0.544383  0.110923 -1.150994
# 2 -24.475600 -0.115648 -0.301104 -1.478522 -0.719844 -0.460639  1.057122
# 3  13.476831 -1.196207  0.812526  1.356240 -0.072010  1.003533  0.361636
# 4   3.505322 -0.808494 -0.501757  0.915402  0.328751 -0.529760  0.513267
#
#          v7        v8        v9  ...       v12       v13       v14       v15  \
# 0  1.579213  0.767435 -0.469474  ... -0.465730  0.241962 -1.913280 -1.724918
# 1  0.375698 -0.600639 -0.291694  ... -0.013497 -1.057711  0.822545 -1.220844
# 2  0.343618 -1.763040  0.324084  ...  0.611676  1.031000  0.931280 -0.839218
# 3 -0.645120  0.361396  1.538037  ... -2.619745  0.821903  0.087047 -0.299007
# 4  0.097078  0.968645 -0.702053  ... -1.463515  0.296120  0.261055  0.005113
#
#         v16       v17       v18       v19       v20       v21
# ...

# %%
df.corr()['Target'].sort_values()[-2]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_19016\1076136234.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.corr()['Target'].sort_values()[-2]
# 0.6270251925517436

# %%
features = [f'v{i}' for i in range(1, 22)]
formula = 'Target ~ ' + ' + '.join(features)

from statsmodels.formula.api import ols
model = ols(formula, data=df).fit()

model.params['v2']
# Out:
# 6.4403013648430685

# %%
model.pvalues.max()
# Out:
# 0.9265545986907606

# %%
import pandas as pd 
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3_t.csv')
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       1
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
from statsmodels.formula.api import logit
train=df[:210]
test=df[210:]

# 종속변수와 독립변수 설정
y = train['target']
X = train.drop('target', axis=1)


# 로지스틱 회귀모형 적합
model = logit('target~age+sex+cp+trestbps+chol+fbs+restecg+thalach+exang+oldpeak+slope+ca+thal',data=train).fit()
model.summary()
np.exp(model.params['age'])
# Out:
# Optimization terminated successfully.
#          Current function value: 0.320236
#          Iterations 7
# 0.9944442574640204

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# GLM을 이용한 로지스틱 회귀
model_glm = smf.glm(
    'target ~ age + sex + cp + trestbps + chol + fbs + restecg + thalach + exang + oldpeak + slope + ca + thal',
    data=train,
    family=sm.families.Binomial()
).fit()

# 잔차 이탈도 및 로그우도
print("📉 Residual Deviance:", model_glm.deviance)
print("📊 Null Deviance:", model_glm.null_deviance)
print("🔢 Log-Likelihood:", model_glm.llf)
# Out:
# 📉 Residual Deviance: 134.49903911342716
# 📊 Null Deviance: 289.21416397368665
# 🔢 Log-Likelihood: -67.24951955671358

# %% [markdown]
# # 8회

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p1_1.csv')
df.head(5)
# Out:
#        대륙       국가명  소비량
# 0  Africa   Algeria   25
# 1  Africa    Angola  217
# 2  Africa     Benin   34
# 3  Africa  Botswana  173
# 4  Africa   Burundi   88

# %%
df.groupby('대륙')['소비량'].mean().sort_values(ascending=False).values[1]
# Out:
# 175.08333333333334

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p1_2.csv')
df.head(5)
# Out:
#        국가       관광      방문    유학연수    취업     기타
# 0    뉴질랜드  24724.0  6320.0  4911.0  56.0  637.0
# 1    피  지   3889.0   564.0    98.0  15.0   40.0
# 2     벨기에    243.0    58.0    30.0   7.0   25.0
# 3     멕시코   1069.0   335.0   103.0  32.0   48.0
# 4  우즈베키스탄   3994.0  1456.0    97.0   4.0  137.0

# %%
df['total']= df['관광'] + df.방문 + df.유학연수 +df.취업+df.기타

# %%
df['관광 비율'] = df.관광 / df.total

# %%
tt = df.sort_values(by='관광 비율', ascending=False)['국가'].values[1]

# %%
be = df[df['국가']==tt]['취업'].values
be
# Out:
# array([22.])

# %%
tt2 = df.sort_values(by='관광', ascending=False)['국가'].values[2]

# %%
af = df[df['국가']==tt2]['방문'].values
af
# Out:
# array([30813.])

# %%
str((be+af).astype(int))
# Out:
# '[30835]'

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p1_3.csv')
df.head(5)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
df['CO(GT)'] = mm.fit_transform(df[['CO(GT)']])
df['NMHC(GT)'] = mm.fit_transform(df[['NMHC(GT)']])

#ddof=0

# %%
be = df['CO(GT)'].std(ddof=0)
af = df['NMHC(GT)'].std(ddof=0)

round(abs(be-af),3)
# Out:
# 0.266

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p2_train2.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p2_test2.csv')

display(train.head(2))
test.head(2)
# Out:
#         ID   C1   C2   C3   C4        Date  Weekday  Temperature   Humidity  \
# 0  ID_1300  X_2  Y_0  Z_3  W_2  2023-03-27        0    10.533315  88.101605
# 1  ID_1301  X_0  Y_3  Z_2  W_9  2023-10-12        3    -1.698046  42.811039
#
#    Wind_Speed  Precipitation     Pressure  Visibility   Y
# 0   13.632211       7.814899  1046.992484    6.100292  27
# 1    6.165366       1.139649   985.766276    5.720027  -5
#         ID   C1   C2   C3    C4        Date  Weekday  Temperature   Humidity  \
# 0  ID_4780  X_1  Y_2  Z_2  W_11  2023-07-27        3    28.460744  32.869427
# 1   ID_217  X_2  Y_2  Z_0   W_9  2023-09-05        1    33.699748  20.366573
#
#    Wind_Speed  Precipitation     Pressure  Visibility
# 0   13.978067       1.453519   980.152660    3.091170
# 1    9.032971       1.430375  1014.322511    7.788306

# %%
target = train.pop('Y')
train_id = train.pop('ID')
test_id = test.pop('ID')
train.pop('Date')
test.pop('Date')
# Out:
# 0       2023-07-27
# 1       2023-09-05
# 2       2023-01-15
# 3       2023-01-25
# 4       2023-01-15
#            ...
# 1295    2023-03-04
# 1296    2023-06-11
# 1297    2023-04-17
# 1298    2023-07-05
# 1299    2023-11-12
# Name: Date, Length: 1300, dtype: object

# %%
col = train.select_dtypes(include='object').columns
train = pd.get_dummies(train,columns=col)
test = pd.get_dummies(test,columns=col)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(train,target)
pred = model.predict(test)

# %%
pd.DataFrame({'ID':test_id, 'Y':pred})
# Out:
#            ID      Y
# 0     ID_4780  22.98
# 1      ID_217  50.08
# 2     ID_4711  70.13
# 3      ID_968  72.52
# 4     ID_3135 -21.91
# ...       ...    ...
# 1295  ID_2462  30.47
# 1296  ID_5222  -4.20
# 1297  ID_4339  27.54
# 1298  ID_2831  44.45
# 1299   ID_683 -23.73
#
# [1300 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p3_1.csv')
df.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  0.506278 -0.231322  0.759771 -0.172927 -0.687524 -0.556815 -1.381369
# 1  0.017220  1.530047  0.676838  1.533623 -0.516027  0.949166 -1.180669
# 2  1.436089  0.038078 -0.120501  0.914955 -1.504149  0.443893 -0.696385
# 3 -0.926337 -0.665242 -0.106853 -1.111627 -0.127867  0.746742 -0.345943
# 4 -0.350953 -0.044709 -0.421777  1.359772 -1.619690 -0.645908 -1.717975
#
#          X8        X9       X10       X11       X12       X13       X14  \
# 0  1.633690 -0.869129  0.370614  0.615057 -0.416594 -1.175980  0.113494
# 1  1.895021 -1.211768 -1.081109 -1.067039 -0.611829  0.846854 -0.812381
# 2  0.245013  1.221166 -1.387287 -1.762048 -0.556466  0.130129  0.517210
# 3  0.848144  0.374944 -0.951299  1.097359  0.754369 -0.221183 -0.430509
# 4 -0.598477  1.026014 -0.134644 -0.988988  0.513048 -0.886113  0.247288
#
#         X15  Y
# 0 -0.539230  1
# 1  0.823546  0
# 2  1.056730  0
# 3  0.756875  1
# 4 -0.016664  0

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

y = df.pop('Y')
X = df
X = sm.add_constant(X)


model = sm.Logit(y,X).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.060586
#          Iterations 10

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                      Y   No. Observations:                 2500
# Model:                          Logit   Df Residuals:                     2484
# Method:                           MLE   Df Model:                           15
# Date:                Fri, 20 Jun 2025   Pseudo R-squ.:                  0.9126
# Time:                        19:39:57   Log-Likelihood:                -151.47
# converged:                       True   LL-Null:                       -1732.9
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.1997      0.566     -3.883      0.000      -3.310      -1.089
# X1             0.2990      0.171      1.749      0.080      -0.036       0.634
# ...

# %%
X = df[['X1','X7','X8','X11']]

model = sm.Logit(y,X).fit()
round(model.params.sum(),3)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.064609
#          Iterations 10
# 6.819

# %%
import pandas as pd 
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p3_2.csv')
df.head()
# Out:
#    PIQ   Brain  Height  Weight
# 0  124   81.69    64.5     118
# 1  150  103.84    73.3     143
# 2  128   96.54    68.8     172
# 3  134   95.15    65.0     147
# 4  110   92.88    69.0     146

# %%
model = smf.glm('PIQ~Brain+Height+Weight',data=df).fit()
model.params['Brain']
# Out:
# 2.0603667978949503

# %%
data = pd.DataFrame({'Brain':[90],'Height':[70],'Weight':[150]})

model.predict(data)[0]
# Out:
# 105.63556929993507

# %%
from sklearn.metrics import r2_score
y_true = df['PIQ']
y_pred = model.fittedvalues

r2 = r2_score(y_true, y_pred)
print("R²:", r2)
# Out:
# R²: 0.29493921047394
