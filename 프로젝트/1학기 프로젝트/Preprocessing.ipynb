# %%
import pandas as pd
train_data = pd.read_csv('total_df.csv')
train_data
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2576\2015876047.py:2: DtypeWarning: Columns (0,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv('total_df.csv')
#        speaker_id      age      sex    occupation birthplace
# 0             1.0      50대       여성  전문가 및 관련 종사자         제주  \
# 1             1.0      50대       여성  전문가 및 관련 종사자         제주
# 2             1.0      50대       여성  전문가 및 관련 종사자         제주
# 3             1.0      50대       여성  전문가 및 관련 종사자         제주
# 4             1.0      50대       여성  전문가 및 관련 종사자         제주
# ...           ...      ...      ...           ...        ...
# 756078    Unknown  Unknown  Unknown       Unknown    Unknown
# 756079    Unknown  Unknown  Unknown       Unknown    Unknown
# 756080    Unknown  Unknown  Unknown       Unknown    Unknown
# 756081    Unknown  Unknown  Unknown       Unknown    Unknown
# 756082    Unknown  Unknown  Unknown       Unknown    Unknown
#
# ...

# %%
train_data.loc[(train_data.linear_kernel < 0.8) & (train_data.jaccard_similarity < 0.8)]
# Out:
#        speaker_id      age      sex    occupation birthplace
# 0             1.0      50대       여성  전문가 및 관련 종사자         제주  \
# 2             1.0      50대       여성  전문가 및 관련 종사자         제주
# 3             1.0      50대       여성  전문가 및 관련 종사자         제주
# 4             1.0      50대       여성  전문가 및 관련 종사자         제주
# 5             1.0      50대       여성  전문가 및 관련 종사자         제주
# ...           ...      ...      ...           ...        ...
# 756078    Unknown  Unknown  Unknown       Unknown    Unknown
# 756079    Unknown  Unknown  Unknown       Unknown    Unknown
# 756080    Unknown  Unknown  Unknown       Unknown    Unknown
# 756081    Unknown  Unknown  Unknown       Unknown    Unknown
# 756082    Unknown  Unknown  Unknown       Unknown    Unknown
#
#        principal_residence current_residence education
# 0                       제주                제주        대졸  \
# 2                       제주                제주        대졸
# 3                       제주                제주        대졸
# ...
