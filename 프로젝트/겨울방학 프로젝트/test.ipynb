# %%
import pandas as pd

data= pd.read_excel('./발주자_공종별_건설수주액_경상.xlsx')

data
# Out:
# c:\Users\LWG\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       발주자별 공종별 1978.01 1978.02 1978.03 1978.04 1978.05 1978.06 1978.07  \
# 0     수주총액   계   42996   48172   95751  105701  236202  137230  135029
# 1      NaN  건축   33016   22929   63790   58611  166849   99465   65657
# 2      NaN  토목    9980   25243   31961   47090   69353   37765   69372
# 3     공공부문   계    6689   26072   34137   61145  102845   65191   84882
# 4      NaN  건축     804    1427    7456   18322   35819   33177   20426
# 5      NaN  토목    5885   24645   26681   42823   67026   32014   64456
# 6     민간부문   계   36294   22072   61605   44529  132671   70812   49971
# 7      NaN  건축   32199   21502   56325   40262  130344   65061   45156
# 8      NaN  토목    4095     570    5280    4267    2327    5751    4815
# ...
