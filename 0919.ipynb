# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
x = np.arange(5)
y = np.random.randint(0,10,5)
plt.plot(x,y)
plt.show()

# %%
import numpy as np #scatter x영어, y 국어, bar, pie(라이브러리 검색-sizes=[~~~~],labels=?), boxplot
np.random.seed(42) #국 영 수 과 - 함수로 fig, ax = plt.subplots() ax.pie(sizes-a,b,c,d 개수 ,labels=?), ax.set_xticklabels
Score = np.random.randint(100, size=(10,4))
Score
# Out:
# array([[51, 92, 14, 71],
#        [60, 20, 82, 86],
#        [74, 74, 87, 99],
#        [23,  2, 21, 52],
#        [ 1, 87, 29, 37],
#        [ 1, 63, 59, 20],
#        [32, 75, 57, 21],
#        [88, 48, 90, 58],
#        [41, 91, 59, 79],
#        [14, 61, 61, 46]])

# %%
#1번 문제
import matplotlib.pyplot as plt
x = Score[:,1]
y = Score[:,0]
plt.xlabel('English')
plt.ylabel('Korea')
plt.scatter(x,y, marker='^')

# %%
#2번 문제
fig, ax = plt.subplots()
def sub_bar(x):
    xylabel = ['Korea','English','Math','Science']
    labels=plt.xlim(0,100)
    values = x
    ax.bar(labels, values)
sub_bar(Score[:,0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 8>()
#       6     values = x
#       7     ax.bar(labels, values)
# ----> 8 sub_bar(Score[:,0])
#       9 plt.show()
#
# Input In [15], in sub_bar(x)
#       5 labels=plt.xlim(0,100)
#       6 values = x
# ----> 7 ax.bar(labels, values)
#
# File c:\Users\HP1\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# ...

# %%
#3번 문제

# %%
#4번 문제
